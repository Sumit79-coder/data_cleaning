# %%
import pandas as pd

# %%
data = pd.read_excel("/Users/sumitkumargupta/Desktop/Dal /data/three_row.xlsx")

# %%
data
# Out:
#              Samples                      Species  Unnamed: 2 Volume Factor  \
# 0      1. July 5-2018      * Anabaena planctonica         NaN  25 ml     25
# 1    Inflow above 4B7       Tabellaria fenestrata         NaN    NaN    NaN
# 2            10;50 am               Dinobryon sp.         NaN    NaN    NaN
# 3      2. July 5-2018      * Anabaena planctonica         NaN  25 ml     25
# 4    Inflow above 4B7       Tabellaria fenestrata         NaN    NaN    NaN
# ..                ...                         ...         ...    ...    ...
# 124  8. IKP Boat Dock    Microcystis aeruginosa**         NaN  10 ml    NaN
# 125               NaN  Microcystis wesenbergii**          NaN  10 ml    NaN
# 126   August 21, 2019      Aphanizomenon gracile*         NaN  25 ml   10.8
# 127     7. INP Bridge    Microcystis aeruginosa**         NaN  25 ml   10.8
# 128               NaN   Microcystis wesenbergii**         NaN  25 ml   10.8
#
#     n. Counted No. cells / ml
# ...

# %%
drop_extra = data.drop(columns =["Unnamed: 2"])
drop_extra
# Out:
#              Samples                      Species Volume Factor n. Counted  \
# 0      1. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 1    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         72
# 2            10;50 am               Dinobryon sp.    NaN    NaN         55
# 3      2. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 4    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         90
# ..                ...                         ...    ...    ...        ...
# 124  8. IKP Boat Dock    Microcystis aeruginosa**  10 ml    NaN        257
# 125               NaN  Microcystis wesenbergii**   10 ml    NaN         61
# 126   August 21, 2019      Aphanizomenon gracile*  25 ml   10.8       1234
# 127     7. INP Bridge    Microcystis aeruginosa**  25 ml   10.8        908
# 128               NaN   Microcystis wesenbergii**  25 ml   10.8         71
#
#     No. cells / ml
# 0               NaN
# 1              2.88
# ...

# %%
drop_nans = drop_extra[drop_extra["Species"].notna()]
drop_nans
# Out:
#              Samples                      Species Volume Factor n. Counted  \
# 0      1. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 1    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         72
# 2            10;50 am               Dinobryon sp.    NaN    NaN         55
# 3      2. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 4    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         90
# ..                ...                         ...    ...    ...        ...
# 124  8. IKP Boat Dock    Microcystis aeruginosa**  10 ml    NaN        257
# 125               NaN  Microcystis wesenbergii**   10 ml    NaN         61
# 126   August 21, 2019      Aphanizomenon gracile*  25 ml   10.8       1234
# 127     7. INP Bridge    Microcystis aeruginosa**  25 ml   10.8        908
# 128               NaN   Microcystis wesenbergii**  25 ml   10.8         71
#
#     No. cells / ml
# 0               NaN
# 1              2.88
# ...

# %%
column_values = []
counter = 0
for i in range(0,129):
    if i%3 == 0:
        counter += 1
    column_values.append(counter)
column_values
# Out:
# [1,
#  1,
#  1,
#  2,
#  2,
#  2,
#  3,
#  3,
#  3,
#  4,
#  4,
#  4,
#  5,
#  5,
#  5,
#  6,
#  6,
#  6,
#  7,
#  7,
#  7,
#  8,
#  8,
#  8,
#  9,
#  9,
#  9,
#  10,
#  10,
#  10,
#  11,
#  11,
#  11,
#  12,
#  12,
#  12,
#  13,
#  13,
#  13,
#  14,
#  14,
#  14,
#  15,
#  15,
#  15,
#  16,
#  16,
#  16,
#  17,
#  17,
#  17,
#  18,
#  18,
#  18,
#  19,
#  19,
#  19,
#  20,
#  20,
#  20,
#  21,
#  21,
#  21,
#  22,
#  22,
#  22,
#  23,
#  23,
#  23,
#  24,
#  24,
#  24,
#  25,
#  25,
#  25,
#  26,
#  26,
#  26,
#  27,
#  27,
#  27,
#  28,
#  28,
#  28,
#  29,
#  29,
#  29,
#  30,
#  30,
#  30,
#  31,
#  31,
#  31,
#  32,
#  32,
#  32,
#  33,
#  33,
#  33,
#  34,
#  34,
#  34,
#  35,
#  35,
#  35,
#  36,
#  36,
#  36,
#  37,
#  37,
#  37,
#  38,
#  38,
#  38,
#  39,
#  39,
#  39,
#  40,
#  40,
#  40,
#  41,
#  41,
#  41,
#  42,
#  42,
#  42,
#  43,
#  43,
#  43]

# %%
iter_cols = drop_nans
iter_cols["Iteration"] = column_values
iter_cols
# Out:
#              Samples                      Species Volume Factor n. Counted  \
# 0      1. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 1    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         72
# 2            10;50 am               Dinobryon sp.    NaN    NaN         55
# 3      2. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 4    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         90
# ..                ...                         ...    ...    ...        ...
# 124  8. IKP Boat Dock    Microcystis aeruginosa**  10 ml    NaN        257
# 125               NaN  Microcystis wesenbergii**   10 ml    NaN         61
# 126   August 21, 2019      Aphanizomenon gracile*  25 ml   10.8       1234
# 127     7. INP Bridge    Microcystis aeruginosa**  25 ml   10.8        908
# 128               NaN   Microcystis wesenbergii**  25 ml   10.8         71
#
#     No. cells / ml   Iteration
# 0               NaN          1
# ...

# %%
data.head(125)
# Out:
#              Samples                    Species  Unnamed: 2 Volume Factor  \
# 0      1. July 5-2018    * Anabaena planctonica         NaN  25 ml     25
# 1    Inflow above 4B7     Tabellaria fenestrata         NaN    NaN    NaN
# 2            10;50 am             Dinobryon sp.         NaN    NaN    NaN
# 3      2. July 5-2018    * Anabaena planctonica         NaN  25 ml     25
# 4    Inflow above 4B7     Tabellaria fenestrata         NaN    NaN    NaN
# ..                ...                       ...         ...    ...    ...
# 120        4. 4B6 TCK                     No BG         NaN  25 ml    NaN
# 121   August 12, 2019      (detritus + diatoms)         NaN    NaN    NaN
# 122               NaN           Chroococcus sp.         NaN    NaN    NaN
# 123  8. IKP Boat Dock    Aphanizomenon gracile*         NaN  10 ml    NaN
# 124   August 12, 2019  Microcystis aeruginosa**         NaN  10 ml    NaN
#
#     n. Counted No. cells / ml
# 0          NaN             NaN
# ...

# %%
iter_cols.head(40)
# Out:
#             Samples                  Species Volume Factor n. Counted  \
# 0     1. July 5-2018  * Anabaena planctonica  25 ml     25        NaN
# 1   Inflow above 4B7   Tabellaria fenestrata    NaN    NaN         72
# 2           10;50 am           Dinobryon sp.    NaN    NaN         55
# 3     2. July 5-2018  * Anabaena planctonica  25 ml     25        NaN
# 4   Inflow above 4B7   Tabellaria fenestrata    NaN    NaN         90
# 5           10;50 am           Dinobryon sp.    NaN    NaN         81
# 6     3. July 5-2018  * Anabaena planctonica  25 ml     25         56
# 7    between 4B6-4B7   Tabellaria fenestrata    NaN    NaN        150
# 8           11:00:00           Dinobryon sp.    NaN    NaN        136
# 9     4. july 5-2018  * Anabaena planctonica  25 ml     25         66
# 10               4B6   Tabellaria fenestrata    NaN    NaN         72
# 11          11;05 am           Dinobryon sp.    NaN    NaN        211
# ...

# %%
iter_cols.tail(40)
# Out:
#                Samples                        Species Volume Factor  \
# 89             10:30:00                 Dinobryon sp.    NaN     39
# 90     28th August 2018         Anabaena planctonica*  10 ml    NaN
# 91             Intel OE         Snowella lacustris **    NaN    NaN
# 92             09:45:00                 Dinobryon sp.    NaN    NaN
# 93           17/10/2022        Aphanizomenon gracile*    931   1 ml
# 94              INP-001    Microcystis flos-aquae****    649    NaN
# 95                  NaN  Microcystis wessenbergii****    134    NaN
# 96           29/09/2022        Aphanizomenon gracile*    127  25 ml
# 97              INP-001  Microcystis wessenbergii****    146    NaN
# 98                  NaN    Microcystis flos-aquae****    381    NaN
# 99            8/09/2022        Aphanizomenon gracile*   1077  25 ml
# 100             INP-001  Microcystis wessenbergii****     81    NaN
# 101                 NaN    Microcystis flos-aquae****   2877    NaN
# ...

# %%
date_dataframe = iter_cols.iloc[0::3]
date_dataframe.drop(columns=["Species", "Volume", "Factor", "n. Counted", "No. cells / ml "], inplace = True)
date_dataframe.rename(columns={ date_dataframe.columns[0]: "Date" }, inplace=True)
date_dataframe
# Out:
# /var/folders/5v/lql48p0n3zvctx2bfslbbwzm0000gn/T/ipykernel_5257/2333530649.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_dataframe.drop(columns=["Species", "Volume", "Factor", "n. Counted", "No. cells / ml "], inplace = True)
# /var/folders/5v/lql48p0n3zvctx2bfslbbwzm0000gn/T/ipykernel_5257/2333530649.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   date_dataframe.rename(columns={ date_dataframe.columns[0]: "Date" }, inplace=True)
#                    Date  Iteration
# 0        1. July 5-2018          1
# 3        2. July 5-2018          2
# 6        3. July 5-2018          3
# ...

# %%
time_dataframe = iter_cols.iloc[2::3]
time_dataframe.drop(columns=["Species", "Volume", "Factor", "n. Counted", "No. cells / ml "], inplace = True)
time_dataframe.rename(columns={ time_dataframe.columns[0]: "Time" }, inplace=True)
time_dataframe
# Out:
# /var/folders/5v/lql48p0n3zvctx2bfslbbwzm0000gn/T/ipykernel_5257/1905860216.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_dataframe.drop(columns=["Species", "Volume", "Factor", "n. Counted", "No. cells / ml "], inplace = True)
# /var/folders/5v/lql48p0n3zvctx2bfslbbwzm0000gn/T/ipykernel_5257/1905860216.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_dataframe.rename(columns={ time_dataframe.columns[0]: "Time" }, inplace=True)
#          Time  Iteration
# 2    10;50 am          1
# 5    10;50 am          2
# 8    11:00:00          3
# 11   11;05 am          4
# 14   11:13:00          5
# ...

# %%
location_dataframe = iter_cols.iloc[1::3]
location_dataframe.drop(columns=["Species", "Volume", "Factor", "n. Counted", "No. cells / ml "], inplace = True)
location_dataframe.rename(columns={ location_dataframe.columns[0]: "Location" }, inplace=True)
location_dataframe
# Out:
# /var/folders/5v/lql48p0n3zvctx2bfslbbwzm0000gn/T/ipykernel_5257/1688455136.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_dataframe.drop(columns=["Species", "Volume", "Factor", "n. Counted", "No. cells / ml "], inplace = True)
# /var/folders/5v/lql48p0n3zvctx2bfslbbwzm0000gn/T/ipykernel_5257/1688455136.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_dataframe.rename(columns={ location_dataframe.columns[0]: "Location" }, inplace=True)
#               Location  Iteration
# 1     Inflow above 4B7          1
# 4     Inflow above 4B7          2
# 7      between 4B6-4B7          3
# ...

# %%
no_Date_dataframe = iter_cols.drop(iter_cols.index[0::3])

no_Date_dataframe
# Out:
#              Samples                      Species Volume Factor n. Counted  \
# 1    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         72
# 2            10;50 am               Dinobryon sp.    NaN    NaN         55
# 4    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         90
# 5            10;50 am               Dinobryon sp.    NaN    NaN         81
# 7     between 4B6-4B7       Tabellaria fenestrata    NaN    NaN        150
# ..                ...                         ...    ...    ...        ...
# 122               NaN             Chroococcus sp.    NaN    NaN        NaN
# 124  8. IKP Boat Dock    Microcystis aeruginosa**  10 ml    NaN        257
# 125               NaN  Microcystis wesenbergii**   10 ml    NaN         61
# 127     7. INP Bridge    Microcystis aeruginosa**  25 ml   10.8        908
# 128               NaN   Microcystis wesenbergii**  25 ml   10.8         71
#
#     No. cells / ml   Iteration
# 1              2.88          1
# ...

# %%
final = pd.merge(left=no_Date_dataframe,right=date_dataframe, how = "inner", on="Iteration")
final_1 = pd.merge(left=final,right=location_dataframe, how = "inner", on="Iteration")
final_1
# Out:
#             Samples                      Species Volume Factor n. Counted  \
# 0   Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         72
# 1           10;50 am               Dinobryon sp.    NaN    NaN         55
# 2   Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         90
# 3           10;50 am               Dinobryon sp.    NaN    NaN         81
# 4    between 4B6-4B7       Tabellaria fenestrata    NaN    NaN        150
# ..               ...                         ...    ...    ...        ...
# 81               NaN             Chroococcus sp.    NaN    NaN        NaN
# 82  8. IKP Boat Dock    Microcystis aeruginosa**  10 ml    NaN        257
# 83               NaN  Microcystis wesenbergii**   10 ml    NaN         61
# 84     7. INP Bridge    Microcystis aeruginosa**  25 ml   10.8        908
# 85               NaN   Microcystis wesenbergii**  25 ml   10.8         71
#
#    No. cells / ml   Iteration             Date          Location
# ...

# %%
final_1 = pd.merge(left=final,right=time_dataframe, how = "inner", on="Iteration", suffixes=('', '_right'))
final_1
# Out:
#              Samples                        Species Volume Factor n. Counted  \
# 0    Inflow above 4B7         Tabellaria fenestrata    NaN    NaN         72
# 1    Inflow above 4B7         Tabellaria fenestrata    NaN    NaN         90
# 2     between 4B6-4B7         Tabellaria fenestrata    NaN    NaN        150
# 3                 4B6         Tabellaria fenestrata    NaN    NaN         72
# 4                 4B5         Tabellaria fenestrata    NaN    NaN        104
# 5                 4B4         Tabellaria fenestrata    NaN   0.77         21
# 6                 4B3         Tabellaria fenestrata    NaN   0.39         16
# 7                 4B2         Tabellaria fenestrata    NaN    1.5        NaN
# 8                 4B1         Tabellaria fenestrata    NaN    1.5        NaN
# 9                   4         Tabellaria fenestrata    NaN   0.77          8
# 10                 4A         Tabellaria fenestrata    NaN    1.5        NaN
# ...

# %%
final = pd.merge(left=iter_cols, right=date_dataframe, how = "inner", on="Iteration")
final_1 = pd.merge(left=final, right=time_dataframe, how = "inner", on="Iteration")
final_2 = pd.merge(left=final_1, right=location_dataframe, how = "inner", on="Iteration")
final_2
# Out:
#              Samples                      Species Volume Factor n. Counted  \
# 0      1. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 1    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         72
# 2            10;50 am               Dinobryon sp.    NaN    NaN         55
# 3      2. July 5-2018      * Anabaena planctonica  25 ml     25        NaN
# 4    Inflow above 4B7       Tabellaria fenestrata    NaN    NaN         90
# ..                ...                         ...    ...    ...        ...
# 124  8. IKP Boat Dock    Microcystis aeruginosa**  10 ml    NaN        257
# 125               NaN  Microcystis wesenbergii**   10 ml    NaN         61
# 126   August 21, 2019      Aphanizomenon gracile*  25 ml   10.8       1234
# 127     7. INP Bridge    Microcystis aeruginosa**  25 ml   10.8        908
# 128               NaN   Microcystis wesenbergii**  25 ml   10.8         71
#
# ...

# %%
print(no_Date_no_time_dataframe.shape[0])
print(date_dataframe.shape[0])
print(time_dataframe.shape[0])
print(final.shape[0])
# Out:
# 86
# 43
# 43
# 86

# %%
final_.to_excel(r'/Users/sumitkumargupta/Desktop/Dal /data/algar_result.xlsx', sheet_name='Sheet1', index = False)
